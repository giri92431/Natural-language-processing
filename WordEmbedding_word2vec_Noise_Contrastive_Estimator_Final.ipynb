# %%
import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

# %%
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
from tensorflow.contrib.tensorboard.plugins import projector

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

# %%
parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# %%
# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
    os.makedirs(FLAGS.log_dir)

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
        local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
    statinfo = os.stat(local_filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
    return local_filename

# %%
filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
"""Extract the first file enclosed in a zip file as a list of words."""
def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

# %%
vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

# %%
"""Process raw inputs into a dataset."""
def build_dataset(words, n_words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)

data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# %%
# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

# %%
with graph.as_default():

  # Input data.
    with tf.name_scope('inputs'):
        train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        with tf.name_scope('embeddings'):
            embeddings = tf.Variable(
              tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
            embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
        nce_weights = tf.Variable(
            tf.truncated_normal(
                [vocabulary_size, embedding_size],
                stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(
            tf.nn.nce_loss(
                weights=nce_weights,
                biases=nce_biases,
                labels=train_labels,
                inputs=embed,
                num_sampled=num_sampled,
                num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
    tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
    with tf.name_scope('optimizer'):
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Merge all summaries.
    merged = tf.summary.merge_all()

    # Add variable initializer.
    init = tf.global_variables_initializer()

    # Create a saver.
    saver = tf.train.Saver()

# %%
# Step 5: Begin training.
num_steps = 200001

# %%
with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  298.682037354
# Nearest to people: password, usury, originates, vistula, encroachment, doodle, staten, turquoise,
# Nearest to american: administratives, arrive, mobilizing, tensions, aldermen, fridays, homeopathic, fantasies,
# Nearest to there: radiative, surrogate, velvet, capitalised, vlaams, jacqueline, torpedo, subduction,
# Nearest to i: hinckley, galahad, liking, governments, accumulation, prophesy, flavoured, sturluson,
# Nearest to not: skyview, possibly, bordered, feminists, memphis, igf, unmatched, hadn,
# Nearest to s: serotonin, tan, stately, redesign, artefact, learns, pound, gaining,
# Nearest to such: mutual, queensberry, lejeune, ridge, mordecai, mare, humiliating, hades,
# Nearest to eight: outweighs, synagogues, predicament, mideast, dug, fets, pulleys, resign,
# Nearest to united: tipperary, morita, megiddo, depressions, swell, fire, renewed, mbeki,
# Nearest to which: requested, acceptor, shipments, unlike, colonies, whispered, confined, genitalia,
# Nearest to two: spiced, untold, ebionites, apocryphal, qualifies, parting, popularizer, contaminated,
# Nearest to during: umi, shaken, legitimized, kalat, pai, learning, invariants, maintainers,
# Nearest to seven: rolls, lighting, enthroned, frigates, bamberger, disarmed, marines, numerical,
# Nearest to other: ufc, dispensationalism, innovated, qualifiers, remarking, harms, jabir, raccoon,
# Nearest to also: pfaff, enacts, culbert, qarase, thx, aphrodite, glitch, vulnerability,
# Nearest to for: halfwidth, widower, yaqub, hollow, venom, folded, pinchcliffe, flowed,
# Average loss at step  2000 :  113.590185562
# Average loss at step  4000 :  53.2452023077
# Average loss at step  6000 :  33.8340794871
# Average loss at step  8000 :  23.0497545853
# Average loss at step  10000 :  17.7319043429
# Nearest to people: disneyland, password, implementation, iowa, no, italy, usury, great,
# Nearest to american: and, arrive, escape, marvel, drawings, produces, township, debian,
# Nearest to there: torpedo, velvet, james, township, dulcimer, dor, game, disneyland,
# Nearest to i: skin, painter, township, depths, governments, dor, operators, caching,
# Nearest to not: skyview, possibly, evil, problem, spelling, memphis, which, course,
# Nearest to s: and, zero, dienes, township, typhoid, serotonin, cc, draugr,
# Nearest to such: mutual, ridge, hero, dienes, known, observations, stored, overnight,
# Nearest to eight: nine, zero, dor, township, four, five, dienes, hz,
# Nearest to united: fire, township, dor, braque, nf, follow, renewed, depressions,
# Nearest to which: benz, requested, colonies, confined, township, that, UNK, a,
# Nearest to two: one, township, hz, nine, three, zero, eight, in,
# Nearest to during: devoted, learning, perceived, of, wicca, township, shaken, rick,
# Nearest to seven: zero, township, cc, nine, dor, beautiful, eight, four,
# Nearest to other: astrology, varphi, arthur, atheism, study, draco, township, eurocents,
# Nearest to also: it, UNK, comprising, created, job, dedham, fingers, divide,
# Nearest to for: and, in, of, by, township, biological, to, UNK,
# Average loss at step  12000 :  14.0228426775
# Average loss at step  14000 :  11.2345343914
# Average loss at step  16000 :  9.32439548671
# Average loss at step  18000 :  8.93055586839
# Average loss at step  20000 :  7.98820331681
# Nearest to people: password, disneyland, implementation, italy, usury, no, crown, originates,
# Nearest to american: and, arrive, elephants, marvel, aldermen, produces, escape, where,
# Nearest to there: it, velvet, drinkordie, torpedo, which, dulcimer, james, surrogate,
# Nearest to i: depths, skin, governments, township, painter, operators, accumulation, liking,
# Nearest to not: skyview, drinkordie, which, it, pegasus, evil, ordinarily, also,
# Nearest to s: and, zero, dienes, the, nine, boost, township, of,
# Nearest to such: mutual, known, ridge, dienes, hero, overnight, resolve, observations,
# Nearest to eight: nine, five, four, zero, dor, township, seven, three,
# Nearest to united: fire, township, depressions, braque, dor, nf, renewed, unitarian,
# Nearest to which: that, this, benz, township, and, it, colonies, confined,
# Nearest to two: one, three, five, four, township, eight, hz, seven,
# Nearest to during: in, of, devoted, on, intents, perceived, learning, from,
# Nearest to seven: nine, zero, eight, township, four, dor, six, two,
# Nearest to other: neighbour, astrology, varphi, arthur, study, cleaner, overly, subgroups,
# Nearest to also: it, comprising, which, who, UNK, created, eight, not,
# Nearest to for: in, and, of, township, by, bigg, with, keen,
# Average loss at step  22000 :  7.420482844
# Average loss at step  24000 :  6.96546966064
# Average loss at step  26000 :  6.63548594069
# Average loss at step  28000 :  6.30949130774
# Average loss at step  30000 :  5.9666148296
# Nearest to people: password, disneyland, crown, implementation, bab, italy, usury, eur,
# Nearest to american: arrive, elephants, and, marvel, aldermen, wembley, ordovician, escape,
# Nearest to there: it, which, they, velvet, drinkordie, torpedo, also, emulsion,
# Nearest to i: depths, skin, neutronic, operators, ostensibly, township, accumulation, dor,
# Nearest to not: it, skyview, also, drinkordie, pegasus, often, evil, which,
# Nearest to s: and, zero, erg, six, boost, dienes, UNK, the,
# Nearest to such: known, mutual, ridge, hero, dienes, well, overnight, talal,
# Nearest to eight: nine, five, four, seven, six, zero, three, dor,
# Nearest to united: fire, depressions, township, frankfort, braque, entrepreneurship, nf, dor,
# Nearest to which: that, this, also, it, township, and, one, benz,
# Nearest to two: three, four, one, five, six, eight, seven, township,
# Nearest to during: from, in, of, on, sada, devoted, intents, legitimized,
# Nearest to seven: eight, nine, six, four, five, zero, three, township,
# Nearest to other: astrology, neighbour, varphi, arthur, qualifiers, overly, cleaner, study,
# Nearest to also: it, which, comprising, who, not, that, there, had,
# Nearest to for: in, with, and, of, keen, or, to, at,
# Average loss at step  32000 :  5.76003937113
# Average loss at step  34000 :  5.70190512145
# Average loss at step  36000 :  5.75858080304
# Average loss at step  38000 :  5.52191842294
# Average loss at step  40000 :  5.38654801702
# Nearest to people: password, disneyland, bab, italy, implementation, crown, usury, imap,
# Nearest to american: administratives, arrive, and, marvel, elephants, aldermen, netbios, christie,
# Nearest to there: it, they, which, drinkordie, he, also, velvet, often,
# Nearest to i: depths, UNK, it, taunus, operators, township, dor, liking,
# Nearest to not: it, skyview, also, often, feminists, pegasus, drinkordie, there,
# Nearest to s: and, boost, zero, erg, taunus, dienes, six, stenella,
# Nearest to such: known, well, ridge, mutual, dienes, hero, historical, acknowledge,
# Nearest to eight: nine, seven, five, six, four, zero, three, dor,
# Nearest to united: fire, depressions, frankfort, bullock, criticize, walsh, township, unitarian,
# Nearest to which: that, this, and, also, township, it, what, one,
# Nearest to two: three, five, four, six, seven, one, eight, township,
# Nearest to during: from, in, on, after, intents, sada, at, of,
# Nearest to seven: eight, six, nine, four, five, three, two, zero,
# Nearest to other: astrology, varphi, neighbour, skate, many, qualifiers, arthur, folksong,
# Nearest to also: which, it, who, comprising, not, often, mondial, there,
# Nearest to for: with, to, of, and, or, in, at, keen,
# Average loss at step  42000 :  5.71398307478
# Average loss at step  44000 :  5.28904221153
# Average loss at step  46000 :  5.22279702556
# Average loss at step  48000 :  5.17888889682
# Average loss at step  50000 :  5.03480149829
# Nearest to people: password, disneyland, szko, italy, bab, emptive, crown, implementation,
# Nearest to american: administratives, british, arrive, and, marvel, netbios, elephants, molds,
# Nearest to there: it, they, which, he, velvet, drinkordie, often, ve,
# Nearest to i: depths, taunus, UNK, operators, township, three, g, flintlock,
# Nearest to not: often, it, also, skyview, usually, feminists, still, pegasus,
# Nearest to s: and, zero, erg, boost, his, the, of, taunus,
# Nearest to such: known, well, dienes, ridge, mutual, overnight, hero, loi,
# Nearest to eight: seven, nine, six, five, four, zero, three, dor,
# Nearest to united: fire, depressions, township, frankfort, mbeki, braque, walsh, bullock,
# Nearest to which: that, this, also, it, township, but, what, boris,
# Nearest to two: three, four, five, one, six, seven, eight, modula,
# Nearest to during: in, from, on, after, sada, by, under, roaming,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to other: varphi, many, astrology, neighbour, yourdon, szko, including, folksong,
# Nearest to also: which, it, who, comprising, not, often, mondial, sometimes,
# Nearest to for: with, to, or, keen, of, in, after, bigg,
# Average loss at step  52000 :  4.96020693624
# Average loss at step  54000 :  5.08674683368
# Average loss at step  56000 :  5.12509993327
# Average loss at step  58000 :  5.0780808394
# Average loss at step  60000 :  4.99480371356
# Nearest to people: password, italy, disneyland, bab, emptive, szko, crown, usury,
# Nearest to american: administratives, british, arrive, marvel, aldermen, affording, molds, adipose,
# Nearest to there: it, they, which, he, often, velvet, eurocents, taunus,
# Nearest to i: depths, we, it, operators, they, he, taunus, township,
# Nearest to not: often, it, skyview, usually, feminists, to, still, also,
# Nearest to s: and, zero, boost, erg, taunus, his, stenella, or,
# Nearest to such: known, well, dienes, ridge, loi, historical, abv, talal,
# Nearest to eight: nine, seven, six, five, four, three, zero, dor,
# Nearest to united: fire, depressions, gkos, frankfort, mbeki, walsh, criticize, bullock,
# Nearest to which: that, this, also, and, it, what, township, but,
# Nearest to two: three, four, five, six, one, seven, eight, modula,
# Nearest to during: in, from, after, on, roaming, sada, at, under,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to other: many, including, astrology, yourdon, neighbour, some, varphi, szko,
# Nearest to also: which, often, comprising, who, sometimes, it, mondial, not,
# Nearest to for: in, with, keen, to, of, rietveld, without, biological,
# Average loss at step  62000 :  4.99212297869
# Average loss at step  64000 :  4.87660828722
# Average loss at step  66000 :  4.77240034842
# Average loss at step  68000 :  4.83274274981
# Average loss at step  70000 :  4.85902600121
# Nearest to people: password, italy, bab, emptive, disneyland, those, szko, owe,
# Nearest to american: british, administratives, arrive, aldermen, marvel, affording, french, rias,
# Nearest to there: it, they, which, he, often, eurocents, usually, taunus,
# Nearest to i: depths, tijuana, g, UNK, we, they, he, taunus,
# Nearest to not: often, it, usually, skyview, they, still, feminists, to,
# Nearest to s: boost, and, zero, his, erg, modula, eight, six,
# Nearest to such: known, well, dienes, these, historical, loi, barristers, many,
# Nearest to eight: six, nine, seven, five, four, three, zero, dor,
# Nearest to united: frankfort, walsh, depressions, fire, gkos, mbeki, criticize, bullock,
# Nearest to which: that, this, also, it, what, there, but, township,
# Nearest to two: three, four, five, six, seven, one, eight, modula,
# Nearest to during: in, after, from, on, sada, roaming, under, at,
# Nearest to seven: six, eight, five, four, three, nine, zero, two,
# Nearest to other: many, including, some, various, astrology, covenants, varphi, yourdon,
# Nearest to also: which, often, who, it, comprising, mondial, sometimes, not,
# Nearest to for: with, of, in, and, rietveld, keen, without, to,
# Average loss at step  72000 :  4.82385478246
# Average loss at step  74000 :  4.81841959202
# Average loss at step  76000 :  4.81595734882
# Average loss at step  78000 :  4.75405172908
# Average loss at step  80000 :  4.79590223062
# Nearest to people: password, italy, emptive, those, bab, disneyland, sld, szko,
# Nearest to american: british, administratives, landesverband, french, mcgwire, arrive, marvel, rias,
# Nearest to there: it, they, he, which, often, usually, eurocents, bankruptcy,
# Nearest to i: depths, we, tijuana, they, landesverband, g, UNK, he,
# Nearest to not: often, skyview, they, usually, still, it, feminists, glas,
# Nearest to s: boost, zero, landesverband, paraffin, essay, hyi, erg, gambler,
# Nearest to such: known, well, these, many, historical, dienes, some, loi,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to united: frankfort, township, walsh, gkos, hyi, criticize, bullock, mbeki,
# Nearest to which: that, this, also, it, but, township, what, one,
# Nearest to two: three, four, five, six, seven, one, eight, landesverband,
# Nearest to during: in, after, from, on, at, under, roaming, sada,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to other: many, various, including, some, covenants, astrology, varphi, tenses,
# Nearest to also: which, often, it, who, sometimes, comprising, popularly, landesverband,
# Nearest to for: keen, without, after, with, of, rietveld, and, in,
# Average loss at step  82000 :  4.71540913117
# Average loss at step  84000 :  4.75776252258
# Average loss at step  86000 :  4.52504765165
# Average loss at step  88000 :  4.65624955785
# Average loss at step  90000 :  4.75203157675
# Nearest to people: password, bab, those, italy, disneyland, sld, landesverband, emptive,
# Nearest to american: british, ieung, administratives, landesverband, french, rias, marvel, arrive,
# Nearest to there: it, they, he, which, usually, often, eurocents, still,
# Nearest to i: depths, g, we, landesverband, taunus, they, tijuana, riso,
# Nearest to not: often, usually, they, still, it, skyview, feminists, you,
# Nearest to s: boost, landesverband, essay, six, bastiat, zero, and, theologians,
# Nearest to such: well, known, these, many, historical, dienes, talal, loi,
# Nearest to eight: seven, six, nine, five, four, zero, three, two,
# Nearest to united: frankfort, walsh, bullock, township, gkos, mbeki, criticize, hyi,
# Nearest to which: that, this, also, what, but, it, township, and,
# Nearest to two: three, six, four, five, seven, one, eight, modula,
# Nearest to during: after, in, from, at, on, roaming, through, under,
# Nearest to seven: six, four, five, eight, nine, three, zero, dor,
# Nearest to other: various, many, including, some, covenants, cisco, varphi, astrology,
# Nearest to also: which, often, it, still, sometimes, who, generally, landesverband,
# Nearest to for: without, and, of, with, in, keen, if, when,
# Average loss at step  92000 :  4.6535770061
# Average loss at step  94000 :  4.63640750909
# Average loss at step  96000 :  4.60762420142
# Average loss at step  98000 :  4.62215602481
# Average loss at step  100000 :  4.36502421999
# Nearest to people: password, bab, those, italy, landesverband, individuals, sld, disneyland,
# Nearest to american: british, ieung, and, administratives, affording, landesverband, adipose, french,
# Nearest to there: it, they, he, which, often, usually, still, you,
# Nearest to i: we, depths, they, g, tijuana, you, t, landesverband,
# Nearest to not: often, usually, it, still, they, skyview, never, feminists,
# Nearest to s: boost, zero, and, his, landesverband, paraffin, modula, stefano,
# Nearest to such: well, known, these, many, historical, yoke, talal, loi,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to united: walsh, frankfort, bullock, criticize, mbeki, township, of, depressions,
# Nearest to which: that, this, also, what, one, but, it, township,
# Nearest to two: three, four, five, six, seven, eight, zero, landesverband,
# Nearest to during: after, in, from, through, at, under, on, sada,
# Nearest to seven: six, eight, five, four, nine, three, dor, township,
# Nearest to other: various, many, including, some, covenants, varphi, folksong, yourdon,
# Nearest to also: often, which, sometimes, who, generally, still, never, now,
# Nearest to for: without, against, after, during, when, rietveld, keen, to,
# Average loss at step  102000 :  4.30294013566
# Average loss at step  104000 :  4.41671728384
# Average loss at step  106000 :  4.45882879508
# Average loss at step  108000 :  4.52409750915
# Average loss at step  110000 :  4.55193359303
# Nearest to people: password, bab, those, italy, landesverband, individuals, axe, szko,
# Nearest to american: british, english, french, ieung, affording, italian, landesverband, adipose,
# Nearest to there: it, they, he, usually, which, still, often, you,
# Nearest to i: we, they, you, depths, t, g, tijuana, UNK,
# Nearest to not: often, usually, it, still, skyview, they, be, you,
# Nearest to s: boost, zero, his, landesverband, township, gambler, dienes, taunus,
# Nearest to such: well, known, these, many, historical, yoke, loi, other,
# Nearest to eight: seven, six, nine, five, four, three, zero, dor,
# Nearest to united: walsh, frankfort, township, criticize, bullock, mbeki, hyi, gkos,
# Nearest to which: that, this, what, but, also, it, township, and,
# Nearest to two: three, four, five, six, seven, eight, zero, one,
# Nearest to during: in, after, from, at, through, under, on, sada,
# Nearest to seven: six, eight, five, four, nine, three, zero, dor,
# Nearest to other: including, many, various, some, covenants, these, astrology, varphi,
# Nearest to also: often, which, still, sometimes, who, popularly, generally, never,
# Nearest to for: without, after, when, against, keen, of, rietveld, if,
# Average loss at step  112000 :  4.53989049649
# Average loss at step  114000 :  4.48770876706
# Average loss at step  116000 :  4.61525785553
# Average loss at step  118000 :  4.60757697976
# Average loss at step  120000 :  4.61215477133
# Nearest to people: password, bab, those, halfwidth, italy, landesverband, individuals, axe,
# Nearest to american: british, english, french, ieung, abv, polish, italian, affording,
# Nearest to there: it, they, he, usually, which, still, often, you,
# Nearest to i: we, they, depths, you, g, t, tijuana, UNK,
# Nearest to not: often, usually, still, it, skyview, never, they, feminists,
# Nearest to s: boost, zero, reincorporated, landesverband, taunus, gambler, modula, his,
# Nearest to such: these, known, well, many, historical, yoke, some, other,
# Nearest to eight: seven, nine, six, four, five, three, zero, dor,
# Nearest to united: walsh, frankfort, township, criticize, mbeki, bullock, hyi, gkos,
# Nearest to which: that, this, what, also, but, who, township, it,
# Nearest to two: three, five, four, six, seven, one, eight, hyi,
# Nearest to during: in, after, from, through, under, on, roaming, at,
# Nearest to seven: six, four, eight, five, nine, three, zero, two,
# Nearest to other: various, many, including, some, covenants, these, different, astrology,
# Nearest to also: often, which, still, sometimes, popularly, now, generally, who,
# Nearest to for: katydids, without, of, keen, after, rietveld, lewin, halfwidth,
# Average loss at step  122000 :  4.57622167516
# Average loss at step  124000 :  4.44575313759
# Average loss at step  126000 :  5.58739237344
# Average loss at step  128000 :  4.74878642797
# Average loss at step  130000 :  4.60554941964
# Nearest to people: those, password, halfwidth, landesverband, bab, italy, individuals, rajonas,
# Nearest to american: british, english, french, ieung, italian, affording, irish, administratives,
# Nearest to there: they, it, he, usually, often, which, still, eurocents,
# Nearest to i: we, g, depths, you, they, ii, landesverband, taunus,
# Nearest to not: often, usually, still, skyview, feminists, never, they, you,
# Nearest to s: zero, boost, certify, landesverband, bastiat, taunus, lep, senseless,
# Nearest to such: these, well, known, many, historical, yoke, regarded, some,
# Nearest to eight: seven, six, nine, four, five, three, dor, rajonas,
# Nearest to united: walsh, lup, frankfort, bullock, criticize, mbeki, coherence, township,
# Nearest to which: that, this, what, also, lup, but, it, rajonas,
# Nearest to two: three, four, five, six, seven, one, lup, eight,
# Nearest to during: in, after, from, safl, through, under, when, on,
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to other: various, many, including, some, varphi, astrology, covenants, different,
# Nearest to also: often, which, still, popularly, sometimes, now, lup, generally,
# Nearest to for: katydids, without, rajonas, when, if, safl, and, of,
# Average loss at step  132000 :  4.53306407332
# Average loss at step  134000 :  4.55182142723
# Average loss at step  136000 :  4.58209551513
# Average loss at step  138000 :  4.46536284006
# Average loss at step  140000 :  4.56494018066
# Nearest to people: those, password, individuals, halfwidth, roadie, bab, italy, landesverband,
# Nearest to american: british, french, english, italian, ieung, australian, irish, polish,
# Nearest to there: they, it, he, usually, often, still, which, you,
# Nearest to i: we, g, you, they, depths, ii, landesverband, taunus,
# Nearest to not: often, usually, still, it, never, skyview, be, feminists,
# Nearest to s: gambler, his, boost, landesverband, bastiat, reincorporated, lep, modula,
# Nearest to such: these, well, known, many, historical, regarded, including, yoke,
# Nearest to eight: seven, six, four, nine, five, three, zero, rajonas,
# Nearest to united: walsh, lup, frankfort, criticize, bullock, mbeki, township, coherence,
# Nearest to which: that, this, what, lup, also, but, however, rajonas,
# Nearest to two: three, four, five, six, one, seven, eight, lup,
# Nearest to during: in, after, safl, at, when, through, under, on,
# Nearest to seven: eight, six, four, five, nine, three, zero, one,
# Nearest to other: various, including, many, some, covenants, different, rajonas, varphi,
# Nearest to also: often, which, still, sometimes, popularly, now, generally, lup,
# Nearest to for: katydids, without, rajonas, after, safl, rstenberg, using, when,
# Average loss at step  142000 :  4.3305499078
# Average loss at step  144000 :  4.27551034713
# Average loss at step  146000 :  4.44251440108
# Average loss at step  148000 :  4.49412217355
# Average loss at step  150000 :  4.33629249287
# Nearest to people: those, password, individuals, roadie, halfwidth, someone, italy, formulate,
# Nearest to american: british, english, french, italian, ieung, irish, affording, polish,
# Nearest to there: it, they, he, usually, often, still, which, eurocents,
# Nearest to i: we, ii, g, you, depths, they, landesverband, taunus,
# Nearest to not: often, usually, still, never, skyview, it, you, glas,
# Nearest to s: boost, lep, landesverband, paraffin, taunus, bastiat, zero, five,
# Nearest to such: well, these, known, many, regarded, historical, yoke, including,
# Nearest to eight: seven, nine, six, four, five, three, zero, dor,
# Nearest to united: walsh, lup, frankfort, mbeki, criticize, bullock, coherence, township,
# Nearest to which: that, this, what, also, but, lup, it, however,
# Nearest to two: three, five, four, six, seven, eight, rajonas, one,
# Nearest to during: after, in, safl, when, through, from, within, until,
# Nearest to seven: eight, six, four, five, nine, three, zero, dor,
# Nearest to other: various, including, many, some, covenants, different, rajonas, lup,
# Nearest to also: often, which, still, now, sometimes, popularly, generally, never,
# Nearest to for: katydids, rajonas, without, after, and, of, if, rstenberg,
# Average loss at step  152000 :  4.45306082416
# Average loss at step  154000 :  4.53054512978
# Average loss at step  156000 :  4.49226955307
# Average loss at step  158000 :  4.38056456852
# Average loss at step  160000 :  4.46258220416
# Nearest to people: those, password, halfwidth, individuals, roadie, someone, bab, formulate,
# Nearest to american: british, english, french, italian, irish, polish, german, ieung,
# Nearest to there: they, it, he, usually, still, often, which, now,
# Nearest to i: we, ii, g, you, depths, they, landesverband, tijuana,
# Nearest to not: often, usually, never, still, it, skyview, always, generally,
# Nearest to s: zero, landesverband, lep, rajonas, hyi, his, isbn, bastiat,
# Nearest to such: these, well, known, many, including, regarded, some, historical,
# Nearest to eight: seven, four, nine, five, six, three, zero, lup,
# Nearest to united: walsh, lup, criticize, mbeki, frankfort, bullock, coherence, township,
# Nearest to which: that, this, what, also, lup, but, it, township,
# Nearest to two: three, four, five, seven, eight, one, rajonas, six,
# Nearest to during: in, after, when, safl, at, within, through, under,
# Nearest to seven: eight, four, five, six, nine, three, zero, rajonas,
# Nearest to other: various, including, many, some, different, silicates, lup, varphi,
# Nearest to also: often, which, still, now, sometimes, popularly, never, generally,
# Nearest to for: katydids, without, rajonas, after, using, and, while, to,
# Average loss at step  162000 :  4.49403517365
# Average loss at step  164000 :  4.51599684191
# Average loss at step  166000 :  4.49985046077
# Average loss at step  168000 :  4.43082438397
# Average loss at step  170000 :  4.44341748047
# Nearest to people: those, individuals, password, halfwidth, landesverband, rajonas, someone, wff,
# Nearest to american: british, english, french, italian, irish, australian, polish, german,
# Nearest to there: they, it, he, usually, often, she, still, now,
# Nearest to i: we, you, ii, g, they, depths, t, landesverband,
# Nearest to not: often, usually, never, still, skyview, you, it, kirchenmusik,
# Nearest to s: boost, zero, paraffin, isbn, lep, hyi, landesverband, agave,
# Nearest to such: these, known, well, many, regarded, including, historical, yoke,
# Nearest to eight: seven, nine, six, four, five, three, zero, lup,
# Nearest to united: walsh, lup, criticize, coherence, mbeki, frankfort, bullock, township,
# Nearest to which: that, this, what, but, it, lup, also, rajonas,
# Nearest to two: three, four, five, six, one, seven, eight, rajonas,
# Nearest to during: in, after, when, through, under, at, safl, within,
# Nearest to seven: eight, four, six, five, nine, three, zero, lup,
# Nearest to other: various, including, many, some, different, lup, silicates, rajonas,
# Nearest to also: often, now, still, which, sometimes, never, popularly, generally,
# Nearest to for: katydids, without, rajonas, while, after, of, safl, when,
# Average loss at step  172000 :  4.44933842409
# Average loss at step  174000 :  4.43744901681
# Average loss at step  176000 :  4.37683520186
# Average loss at step  178000 :  4.4419571898
# Average loss at step  180000 :  4.47088437414
# Nearest to people: those, individuals, halfwidth, password, men, roadie, someone, person,
# Nearest to american: british, english, french, italian, irish, australian, german, polish,
# Nearest to there: it, they, he, usually, she, often, still, we,
# Nearest to i: we, you, ii, g, they, depths, t, landesverband,
# Nearest to not: often, usually, still, never, generally, you, it, kirchenmusik,
# Nearest to s: dasyprocta, boost, his, landesverband, taunus, lep, paraffin, rajonas,
# Nearest to such: these, well, known, many, regarded, historical, including, yoke,
# Nearest to eight: seven, nine, six, five, four, three, zero, reginae,
# Nearest to united: walsh, lup, frankfort, township, criticize, coherence, mbeki, bullock,
# Nearest to which: that, this, what, lup, township, rajonas, but, also,
# Nearest to two: three, four, five, six, eight, seven, rajonas, reginae,
# Nearest to during: after, in, when, through, at, under, within, safl,
# Nearest to seven: eight, six, five, four, nine, three, zero, reginae,
# Nearest to other: various, including, many, some, different, lup, rajonas, silicates,
# Nearest to also: often, still, now, sometimes, which, usually, never, popularly,
# Nearest to for: katydids, without, rajonas, after, if, when, safl, while,
# Average loss at step  182000 :  4.30664718747
# Average loss at step  184000 :  4.36508354914
# Average loss at step  186000 :  4.39968016446
# Average loss at step  188000 :  4.42795731664
# Average loss at step  190000 :  4.41345924592
# Nearest to people: individuals, those, halfwidth, men, landesverband, rajonas, roadie, someone,
# Nearest to american: british, english, french, irish, australian, italian, canadian, german,
# Nearest to there: it, they, he, usually, still, often, she, which,
# Nearest to i: ii, we, you, g, they, depths, iii, landesverband,
# Nearest to not: often, usually, never, still, you, it, generally, always,
# Nearest to s: dasyprocta, taunus, isbn, landesverband, whose, boost, paraffin, reincorporated,
# Nearest to such: these, well, known, many, regarded, including, historical, yoke,
# Nearest to eight: seven, six, five, nine, four, zero, three, lup,
# Nearest to united: walsh, frankfort, lup, criticize, mbeki, township, coherence, bullock,
# Nearest to which: this, that, what, it, also, but, lup, these,
# Nearest to two: three, four, six, five, seven, eight, rajonas, modula,
# Nearest to during: after, in, when, at, through, on, within, before,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to other: various, including, many, different, some, lup, those, silicates,
# Nearest to also: often, still, now, which, sometimes, never, popularly, generally,
# Nearest to for: katydids, without, rajonas, after, while, rstenberg, safl, mjw,
# Average loss at step  192000 :  4.42182767522
# Average loss at step  194000 :  4.45517774522
# Average loss at step  196000 :  4.4313670305
# Average loss at step  198000 :  4.46097882199
# Average loss at step  200000 :  4.42301300287
# Nearest to people: individuals, those, men, halfwidth, roadie, others, someone, password,
# Nearest to american: british, english, irish, australian, french, italian, canadian, polish,
# Nearest to there: it, they, he, usually, still, often, she, now,
# Nearest to i: ii, we, you, g, they, landesverband, depths, iii,
# Nearest to not: often, usually, still, never, generally, always, skyview, it,
# Nearest to s: dasyprocta, certify, his, landesverband, helen, taunus, township, bastiat,
# Nearest to such: these, well, known, many, regarded, including, historical, yoke,
# Nearest to eight: seven, six, nine, four, five, three, zero, lup,
# Nearest to united: walsh, frankfort, lup, township, criticize, coherence, mbeki, bullock,
# Nearest to which: this, that, what, but, also, lup, however, rajonas,
# Nearest to two: three, four, six, five, one, seven, eight, rajonas,
# Nearest to during: in, after, when, before, through, within, at, under,
# Nearest to seven: six, four, five, eight, nine, three, zero, rajonas,
# Nearest to other: various, including, many, some, different, these, lup, yourdon,
# Nearest to also: often, still, now, which, never, sometimes, popularly, generally,
# Nearest to for: katydids, without, after, while, rajonas, when, including, mjw,

# %%
def save_words_embeddings(embeddings,word_counts):
    np.save('embeddings.npy',embeddings)
    
    np.save('words.npy',word_counts)

save_words_embeddings(final_embeddings,data)

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')

    plt.savefig(filename)
    plt.show(filename)

# %%
try:
  # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(
        perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)
